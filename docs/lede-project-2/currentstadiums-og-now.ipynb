# %%
import requests
import pandas as pd

# %%
df = pd.read_csv("stadiums-og-now.csv")
df.head(100)
# Out:
#                             Stadium  Current  Original  Difference
# 0                   Tropicana Field    25025     45369      -20344
# 1                     Rogers Centre    39150     50516      -11366
# 2                 Progressive Field    34830     42865       -8035
# 3       Oriole Park at Camden Yards    44970     48876       -3906
# 4                    Yankee Stadium    46537     50287       -3750
# 5             Guaranteed Rate Field    40615     44321       -3706
# 6                       Coors Field    46897     50200       -3303
# 7   Oakland–Alameda County Coliseum    46847     50000       -3153
# 8                  Kauffman Stadium    37903     40625       -2722
# 9                        Petco Park    39860     42445       -2585
# 10                     Target Field    38544     39504        -960
# 11               Citizens Bank Park    42901     43500        -599
# 12                   Nationals Park    41373     41888        -515
# ...

# %%
df = df.sort_values('Difference', ascending=True)
df
# Out:
#                             Stadium  Current  Original  Difference
# 0                   Tropicana Field    25025     45369      -20344
# 1                     Rogers Centre    39150     50516      -11366
# 2                 Progressive Field    34830     42865       -8035
# 3       Oriole Park at Camden Yards    44970     48876       -3906
# 4                    Yankee Stadium    46537     50287       -3750
# 5             Guaranteed Rate Field    40615     44321       -3706
# 6                       Coors Field    46897     50200       -3303
# 7   Oakland–Alameda County Coliseum    46847     50000       -3153
# 8                  Kauffman Stadium    37903     40625       -2722
# 9                        Petco Park    39860     42445       -2585
# 10                     Target Field    38544     39504        -960
# 11               Citizens Bank Park    42901     43500        -599
# 12                   Nationals Park    41373     41888        -515
# ...

# %%
df.head(5)
# Out:
#                        Stadium  Current  Original  Difference
# 0              Tropicana Field    25025     45369      -20344
# 1                Rogers Centre    39150     50516      -11366
# 2            Progressive Field    34830     42865       -8035
# 3  Oriole Park at Camden Yards    44970     48876       -3906
# 4               Yankee Stadium    46537     50287       -3750

# %%
df.sort_values('Difference', ascending=False).plot.barh(x='Stadium', y='Difference')
# Out:
# <Axes: ylabel='Stadium'>
